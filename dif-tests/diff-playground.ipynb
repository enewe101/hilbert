# %%
import numpy as np
import scipy.sparse
import matplotlib.pyplot as plt

# %%
cooc = scipy.sparse.load_npz("/home/rldata/hilbert-embeddings/cooccurrence/10000-vocab-lowered/1.512-1w-dynamic-10k/Nxx.npz")

# %%
plt.figure(figsize=(15,7))
for i in range(1000):
    row = cooc[i]
    values = sorted(row.toarray()[0])
    plt.plot(range(len(values)), values)

# %%
plt.figure(figsize=(15,7))
plt.plot(range(len(nonzeros)), nonzeros)

# %%
cooc[0].toarray()[0]
# Out:
# array([3.0000e+02, 1.3212e+04, 1.6137e+04, ..., 2.4000e+01, 1.0000e+00,
#        4.0000e+00])

# %%
test / np.array(np.sum(test, axis=1))
# Out:
# array([[0.16666667, 0.22222222, 0.17647059],
#        [0.33333333, 0.33333333, 0.23529412],
#        [0.66666667, 0.66666667, 0.41176471]])

# %%
normalized = []

# %%
for i,s in enumerate(np.sum(test, axis=1)):
    normalized.append(test[i]/s)

# %%
normalized
# Out:
# [array([0.16666667, 0.33333333, 0.5       ]),
#  array([0.22222222, 0.33333333, 0.44444444]),
#  array([0.23529412, 0.35294118, 0.41176471])]
