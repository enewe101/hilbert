# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_losses(fname):
    losses = []
    with open(fname, 'rt', encoding='utf-8') as f:
        for line in f:
            if line[:4] == 'iter':
                losses.append(float(line.split('=')[1]))
    return losses

# %%
def plot_loss(fname):
    losses = load_losses(fname)
    plt.plot(range(len(losses)), losses, label=fname)
    return losses

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
# plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.8-5w-mle-l500-I200-V10k/trace.txt')
# plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.32-5w-mle-l500-I200-V10k/trace.txt')
# plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.128-5w-mle-l500-I300-V10k/trace.txt')
# plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.512-5w-mle-l500-I300-V10k/trace.txt')
# plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.8-5w-map-l500-I200-V10k/trace.txt')
# plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.32-5w-map-l500-I200-V10k/trace.txt')
# plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.128-5w-map-l500-I300-V10k/trace.txt')
plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.512-5w-map-l500-I300-V10k/trace.txt')
plot_loss('/home/rldata/hilbert-embeddings/embeddings/diffusion-hilbert/1.2048-5w-map-l250-I400-V10k/trace.txt')
#plt.xlim(10000, 30000)
# plt.ylim(,4)
plt.legend()
plt.show()

# %%
losses[-100:]
# Out:
# [5.480683906711192e-09,
#  5.4806745808377855e-09,
#  5.480667475410428e-09,
#  5.48066081407228e-09,
#  5.480659037715441e-09,
#  5.480651932288083e-09,
#  5.480648379574404e-09,
#  5.480639941879417e-09,
#  5.480637721433368e-09,
#  5.480627507381541e-09,
#  5.480618625597344e-09,
#  5.480613740616036e-09,
#  5.48060130611816e-09,
#  5.4805884275310746e-09,
#  5.480583986638976e-09,
#  5.480574216676359e-09,
#  5.480574216676359e-09,
#  5.4805679994274215e-09,
#  5.48057244031952e-09,
#  5.4805768812116185e-09,
#  5.48057332849794e-09,
#  5.480561338089274e-09,
#  5.4805560090187555e-09,
#  5.480551124037447e-09,
#  5.4805471272345585e-09,
#  5.48054313043167e-09,
#  5.480534248647473e-09,
#  5.480528031398535e-09,
#  5.480521814149597e-09,
#  5.4805204818819675e-09,
#  5.4805147087222394e-09,
#  5.480505382848833e-09,
#  5.480498721510685e-09,
#  5.480495612886216e-09,
#  5.480494280618586e-09,
#  5.480487175191229e-09,
#  5.4804791815854514e-09,
#  5.480476961139402e-09,
# ...
